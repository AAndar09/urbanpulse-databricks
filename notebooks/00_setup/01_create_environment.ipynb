# %%
# %sql
CREATE SCHEMA IF NOT EXISTS workspace.urbanpulse_bronze;
CREATE SCHEMA IF NOT EXISTS workspace.urbanpulse_silver;
CREATE SCHEMA IF NOT EXISTS workspace.urbanpulse_gold;
CREATE SCHEMA IF NOT EXISTS workspace.urbanpulse_meta;

# %%
# %sql
SHOW SCHEMAS IN workspace;

# %%
# %sql
CREATE VOLUME IF NOT EXISTS
workspace.urbanpulse_meta.landing;
